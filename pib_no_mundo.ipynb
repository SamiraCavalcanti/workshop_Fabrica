# %% [markdown]
# <a href="https://colab.research.google.com/github/SamiraCavalcanti/workshop_Fabrica/blob/main/pib_no_mundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

# %%
df = pd.read_csv('world_country_gdp_usd.csv')

# %%
df.head()
# Out:
#                   Country Name Country Code  year       GDP_USD  \
# 0                        Aruba          ABW  1960           NaN
# 1  Africa Eastern and Southern          AFE  1960  2.129059e+10
# 2                  Afghanistan          AFG  1960  5.377778e+08
# 3   Africa Western and Central          AFW  1960  1.040414e+10
# 4                       Angola          AGO  1960           NaN
#
#    GDP_per_capita_USD
# 0                 NaN
# 1          162.726326
# 2           59.773234
# 3          107.930722
# 4                 NaN

# %%
df.describe()
# Out:
#                year       GDP_USD  GDP_per_capita_USD
# count  16492.000000  1.311800e+04        13115.000000
# mean    1990.500000  1.163688e+12         8106.355825
# std       17.896073  5.227169e+12        16197.061783
# min     1960.000000  8.824448e+06           12.802812
# 25%     1975.000000  2.434815e+09          544.543855
# 50%     1990.500000  1.800584e+10         1852.354673
# 75%     2006.000000  2.169948e+11         7558.324569
# max     2021.000000  9.610010e+13       189487.147100

# %%
df2 = df.drop('year', axis=1)

# %%
df2.head()
# Out:
#                   Country Name Country Code       GDP_USD  GDP_per_capita_USD
# 0                        Aruba          ABW           NaN                 NaN
# 1  Africa Eastern and Southern          AFE  2.129059e+10          162.726326
# 2                  Afghanistan          AFG  5.377778e+08           59.773234
# 3   Africa Western and Central          AFW  1.040414e+10          107.930722
# 4                       Angola          AGO           NaN                 NaN

# %%
df2 = df[['Country Name', 'Country Code', 'GDP_USD','GDP_per_capita_USD']]

# %%
df2.head()
# Out:
#                   Country Name Country Code       GDP_USD  GDP_per_capita_USD
# 0                        Aruba          ABW           NaN                 NaN
# 1  Africa Eastern and Southern          AFE  2.129059e+10          162.726326
# 2                  Afghanistan          AFG  5.377778e+08           59.773234
# 3   Africa Western and Central          AFW  1.040414e+10          107.930722
# 4                       Angola          AGO           NaN                 NaN

# %%
plt.hist(x=df['Country Name'], color='green')
# Out:
# (array([1674., 1612., 1674., 1612., 1674., 1612., 1674., 1612., 1674.,
#         1674.]),
#  array([  0. ,  26.5,  53. ,  79.5, 106. , 132.5, 159. , 185.5, 212. ,
#         238.5, 265. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x=df['GDP_per_capita_USD'], color='yellow')
# Out:
# (array([1.1426e+04, 9.6400e+02, 4.6000e+02, 1.2000e+02, 7.2000e+01,
#         3.4000e+01, 1.2000e+01, 6.0000e+00, 1.1000e+01, 1.0000e+01]),
#  array([1.28028125e+01, 1.89602372e+04, 3.79076717e+04, 5.68551061e+04,
#         7.58025405e+04, 9.47499750e+04, 1.13697409e+05, 1.32644844e+05,
#         1.51592278e+05, 1.70539713e+05, 1.89487147e+05]),
#  <a list of 10 Patch objects>)

# %%
grafico = px.scatter_matrix(df, dimensions=['GDP_per_capita_USD','Country Name'], color='GDP_USD')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
